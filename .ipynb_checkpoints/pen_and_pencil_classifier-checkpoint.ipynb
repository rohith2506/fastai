# %%
from fastai.vision import *

# %%
folder = "pen"
file = "urls_pen.csv"

# %%
folder = "pencil"
file = "urls_pencil.csv"

# %%
path = Path("data/penandpencil")
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('data/penandpencil/pen'), PosixPath('data/penandpencil/pencil')]

# %%
classes = ['pen', 'pencil']

# %%
path/file
# Out:
# PosixPath('data/penandpencil/urls_pencil.csv')

# %%
download_images('data/penandpencil/pen/urls_pen.csv', 'data/penandpencil/pen', max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:08<00:00]
#     </div>
# Error https://store.hp.com/UKStore/Html/Merch/Images/c05523697_1750x1285.jpg HTTPSConnectionPool(host='store.hp.com', port=443): Read timed out. (read timeout=4)

# %%
download_images('data/penandpencil/pencil/urls_pencil.csv', 'data/penandpencil/pencil', max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:05<00:00]
#     </div>

# %%
verify_images('data/penandpencil/pen', delete=True, max_size=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='99', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [99/99 00:00<00:00]
#     </div>
# Image data/penandpencil/pen/00000077.jpg has 1 instead of 3 channels
# cannot identify image file <_io.BufferedReader name='data/penandpencil/pen/00000099.png'>
# cannot identify image file <_io.BufferedReader name='data/penandpencil/pen/00000096.jpg'>
# ...

# %%
verify_images('data/penandpencil/pencil', delete=True, max_size=500)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='100' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [100/100 00:00<00:00]
#     </div>
# /opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py:952: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   ' expressed in bytes should be converted ' +
# ...

# %%
path
# Out:
# PosixPath('data/penandpencil')

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data
# Out:
# ImageDataBunch;
#
# Train: LabelList
# y: CategoryList (152 items)
# [Category pen, Category pen, Category pen, Category pen, Category pen]...
# Path: data/penandpencil
# x: ImageItemList (152 items)
# [Image (3, 500, 311), Image (3, 384, 500), Image (3, 500, 500), Image (3, 500, 500), Image (3, 147, 220)]...
# Path: data/penandpencil;
#
# Valid: LabelList
# y: CategoryList (38 items)
# [Category pencil, Category pencil, Category pencil, Category pen, Category pencil]...
# Path: data/penandpencil
# x: ImageItemList (38 items)
# [Image (3, 500, 500), Image (3, 250, 500), Image (3, 375, 500), Image (3, 500, 500), Image (3, 500, 500)]...
# Path: data/penandpencil;
#
# Test: None

# %%
data.classes
# Out:
# ['pen', 'pencil']

# %%
data.show_batch(rows=3)

# %%
def learn_model(data):
    learn = create_cnn(data, models.resnet34, metrics=error_rate)
    learn.fit_one_cycle(4)
    return learn

# %%
learn = learn_model(data)
# Out:
# Total time: 00:11 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.926236</th>
#     <th>0.750857</th>
#     <th>0.473684</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.836606</th>
#     <th>0.535610</th>
#     <th>0.263158</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.696086</th>
#     <th>0.517239</th>
#     <th>0.236842</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.595230</th>
#     <th>0.497210</th>
#     <th>0.210526</th>
#   </tr>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr = slice(1e-04, 1e-03))
# Out:
# Total time: 00:05 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.330001</th>
#     <th>0.559290</th>
#     <th>0.236842</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.276448</th>
#     <th>0.512427</th>
#     <th>0.184211</th>
#   </tr>
# </table>

# %%
learn.save('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
learn.export()

# %%
torch.device('cpu')
# Out:
# device(type='cpu')

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image('data/penandpencil/test/pen_sample.jpeg')

# %%
img
# Out:
# Image (3, 180, 180)

# %%
learn.predict(img)
# Out:
# (Category pencil, tensor(1), tensor([0.3084, 0.6916]))

# %%
from fastai.widgets import *

losses,idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %%
for path in top_loss_paths:
    print(path.show())
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# ...
